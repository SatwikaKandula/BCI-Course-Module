# %%
import mne
raw = mne.io.read_raw_edf('../DATA/S001R03.edf', preload=True)
raw_filtered = raw.copy()
raw_filtered.filter(8, 30, fir_design='firwin')
print("Filtering done!")
# Out:
# Extracting EDF parameters from /Users/kandulasatwika/Desktop/400_BCI/DATA/S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 265 samples (1.656 s)
#
# Filtering done!
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished

# %%
channels_to_plot = ['C3..', 'C4..', 'Cz..']
raw_filtered.plot(
    duration=10,
    n_channels=3,
    picks=channels_to_plot,
    title='AFTER Filtering — 8-30 Hz',
    show=True,
    block=True
)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# Save filtered EEG data
raw_filtered.save("../DATA/S001R03_filtered_raw.fif", overwrite=True)
print("Filtered EEG saved!")
# Out:
# Writing /Users/kandulasatwika/Desktop/400_BCI/Notebooks/../DATA/S001R03_filtered_raw.fif
# Closing /Users/kandulasatwika/Desktop/400_BCI/Notebooks/../DATA/S001R03_filtered_raw.fif
# [done]
# Filtered EEG saved!
